# %%
# %%cmd
# pip install shapely
# pip install pyproj
# pip install pyogrio
# pip install geopandas[all]
# Out:
# Microsoft Windows [Version 10.0.22631.4890]
# (c) Microsoft Corporation. All rights reserved.
#
# C:\Users\vivgo\OneDrive\Documents\Assignments Spring 2025\HDS5230>pip install shapely
# Requirement already satisfied: shapely in c:\users\vivgo\anaconda3\lib\site-packages (2.0.7)
# Requirement already satisfied: numpy<3,>=1.14 in c:\users\vivgo\anaconda3\lib\site-packages (from shapely) (1.26.4)
#
# C:\Users\vivgo\OneDrive\Documents\Assignments Spring 2025\HDS5230>pip install pyproj
# Requirement already satisfied: pyproj in c:\users\vivgo\anaconda3\lib\site-packages (3.7.1)
# Requirement already satisfied: certifi in c:\users\vivgo\anaconda3\lib\site-packages (from pyproj) (2024.8.30)
#
# C:\Users\vivgo\OneDrive\Documents\Assignments Spring 2025\HDS5230>pip install pyogrio
# Requirement already satisfied: pyogrio in c:\users\vivgo\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: certifi in c:\users\vivgo\anaconda3\lib\site-packages (from pyogrio) (2024.8.30)
# Requirement already satisfied: numpy in c:\users\vivgo\anaconda3\lib\site-packages (from pyogrio) (1.26.4)
# Requirement already satisfied: packaging in c:\users\vivgo\anaconda3\lib\site-packages (from pyogrio) (24.1)
#
# C:\Users\vivgo\OneDrive\Documents\Assignments Spring 2025\HDS5230>pip install geopandas[all]
# Requirement already satisfied: geopandas[all] in c:\users\vivgo\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in c:\users\vivgo\anaconda3\lib\site-packages (from geopandas[all]) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\vivgo\anaconda3\lib\site-packages (from geopandas[all]) (0.10.0)
# Requirement already satisfied: packaging in c:\users\vivgo\anaconda3\lib\site-packages (from geopandas[all]) (24.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\vivgo\anaconda3\lib\site-packages (from geopandas[all]) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\vivgo\anaconda3\lib\site-packages (from geopandas[all]) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\vivgo\anaconda3\lib\site-packages (from geopandas[all]) (2.0.7)
# Requirement already satisfied: psycopg-binary>=3.1.0 in c:\users\vivgo\anaconda3\lib\site-packages (from geopandas[all]) (3.2.5)
# Requirement already satisfied: SQLAlchemy>=1.3 in c:\users\vivgo\anaconda3\lib\site-packages (from geopandas[all]) (2.0.34)
# Requirement already satisfied: geopy in c:\users\vivgo\anaconda3\lib\site-packages (from geopandas[all]) (2.4.1)
# Requirement already satisfied: matplotlib>=3.5.0 in c:\users\vivgo\anaconda3\lib\site-packages (from geopandas[all]) (3.9.2)
# Requirement already satisfied: mapclassify in c:\users\vivgo\anaconda3\lib\site-packages (from geopandas[all]) (2.8.1)
# Requirement already satisfied: xyzservices in c:\users\vivgo\anaconda3\lib\site-packages (from geopandas[all]) (2022.9.0)
# Requirement already satisfied: folium in c:\users\vivgo\anaconda3\lib\site-packages (from geopandas[all]) (0.19.5)
# Requirement already satisfied: GeoAlchemy2 in c:\users\vivgo\anaconda3\lib\site-packages (from geopandas[all]) (0.17.1)
# Requirement already satisfied: pyarrow>=8.0.0 in c:\users\vivgo\anaconda3\lib\site-packages (from geopandas[all]) (16.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vivgo\anaconda3\lib\site-packages (from matplotlib>=3.5.0->geopandas[all]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\vivgo\anaconda3\lib\site-packages (from matplotlib>=3.5.0->geopandas[all]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vivgo\anaconda3\lib\site-packages (from matplotlib>=3.5.0->geopandas[all]) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vivgo\anaconda3\lib\site-packages (from matplotlib>=3.5.0->geopandas[all]) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\vivgo\anaconda3\lib\site-packages (from matplotlib>=3.5.0->geopandas[all]) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vivgo\anaconda3\lib\site-packages (from matplotlib>=3.5.0->geopandas[all]) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vivgo\anaconda3\lib\site-packages (from matplotlib>=3.5.0->geopandas[all]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vivgo\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas[all]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vivgo\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas[all]) (2023.3)
# Requirement already satisfied: certifi in c:\users\vivgo\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas[all]) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\vivgo\anaconda3\lib\site-packages (from SQLAlchemy>=1.3->geopandas[all]) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\vivgo\anaconda3\lib\site-packages (from SQLAlchemy>=1.3->geopandas[all]) (3.0.1)
# Requirement already satisfied: branca>=0.6.0 in c:\users\vivgo\anaconda3\lib\site-packages (from folium->geopandas[all]) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\vivgo\anaconda3\lib\site-packages (from folium->geopandas[all]) (3.1.4)
# Requirement already satisfied: requests in c:\users\vivgo\anaconda3\lib\site-packages (from folium->geopandas[all]) (2.32.3)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\vivgo\anaconda3\lib\site-packages (from geopy->geopandas[all]) (2.0)
# Requirement already satisfied: networkx>=2.7 in c:\users\vivgo\anaconda3\lib\site-packages (from mapclassify->geopandas[all]) (3.3)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\vivgo\anaconda3\lib\site-packages (from mapclassify->geopandas[all]) (1.5.1)
# Requirement already satisfied: scipy>=1.8 in c:\users\vivgo\anaconda3\lib\site-packages (from mapclassify->geopandas[all]) (1.13.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vivgo\anaconda3\lib\site-packages (from jinja2>=2.9->folium->geopandas[all]) (2.1.3)
# Requirement already satisfied: six>=1.5 in c:\users\vivgo\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->geopandas[all]) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\vivgo\anaconda3\lib\site-packages (from scikit-learn>=1.0->mapclassify->geopandas[all]) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\vivgo\anaconda3\lib\site-packages (from scikit-learn>=1.0->mapclassify->geopandas[all]) (3.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vivgo\anaconda3\lib\site-packages (from requests->folium->geopandas[all]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vivgo\anaconda3\lib\site-packages (from requests->folium->geopandas[all]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vivgo\anaconda3\lib\site-packages (from requests->folium->geopandas[all]) (2.2.3)
#
# C:\Users\vivgo\OneDrive\Documents\Assignments Spring 2025\HDS5230>

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point
import random
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import math
from math import sqrt
import copy
from functools import *
import time
import itertools

# %% [markdown]
# ###
# EXPLANATION: In the below code blocks, I will
#
# 1. read the FQHC Locations dataset into gdf - it's a geoDataFrame.
#
# 2. read the population dataset into pop_gdf (I have selected a small fraction of the original dataset to save computation time, and used create_point_column to create the geometry object using lat and lon columns).
#
# ###

# %%
# Read the shapefile
shapefile_path = "MO_2018_Federally_Qualified_Health_Center_Locations"  # Replace with the actual path
gdf = gpd.read_file(shapefile_path)

# %%
print(gdf.crs) # print the coordinate reference system
crs = gdf.crs
# Out:
# EPSG:4326

# %%
gdf.head()
# Out:
#    OBJECTID                      Group_Name  \
# 0         1                         COMTREA
# 1         2  Missouri Highlands Health Care
# 2         3   Central Ozarks Medical Center
# 3         4  Missouri Highlands Health Care
# 4         5           Swope Health Services
#
#                                             Facility  \
# 0                  COMTREA Byrnes Mill Health Center
# 1                            Viburnum Medical Clinic
# 2          Central Ozarks Medical Center At The Lake
# 3  Missouri Highland Medical Clinic - Poplar Bluf...
# 4                         Swope Health Hickman Mills
#
#                                 Address           City     County State  \
# 0            100 Osage Executive Circle  House Springs  Jefferson    MO
# 1               18 Viburnum Center Road       Viburnum       Iron    MO
# 2                  3870 Columbia Avenue    Osage Beach     Miller    MO
# 3  225 Physicians Park Drive, Suite 303   Poplar Bluff     Butler    MO
# 4             8800 Blue Ridge Boulevard    Kansas City    Jackson    MO
#
#      Zip       Phone   Latitude  Longitude Loc_Code  \
# 0  63051  6367893372  38.435946 -90.554678      MAP
# 1  65566  5732445406  37.714620 -91.133983      MAP
# 2  65065  5733027490  38.160258 -92.601463      MAP
# 3  63901  5737856536  36.772568 -90.457206      MAP
# 4  64138  8163213200  38.962882 -94.498847      MAP
#
#                      geometry
# 0  POINT (-90.55472 38.43597)
# 1  POINT (-91.13403 37.71462)
# 2  POINT (-92.60144 38.16025)
# 3  POINT (-90.45724 36.77261)
# 4   POINT (-94.49886 38.9629)

# %%
gdf = gdf.set_index("OBJECTID")

# %%
def create_point_column(df, lon_col, lat_col, crs="EPSG:4326"):
    """
    Creates a geometry column of Point objects from longitude and latitude columns in a DataFrame.

    Args:
        df (pandas.DataFrame): The DataFrame containing longitude and latitude columns.
        lon_col (str): The name of the longitude column.
        lat_col (str): The name of the latitude column.
        crs (str, optional): Coordinate Reference System. Defaults to "EPSG:4326".

    Returns:
        geopandas.GeoDataFrame: A GeoDataFrame with the added geometry column.
    """

    geometry = [Point(xy) for xy in zip(df[lon_col], df[lat_col])]
    gdf = gpd.GeoDataFrame(df, geometry=geometry, crs=crs)
    return gdf

# %%
# Read the shapefile
pop_file_path = "Mo_pop_sim/Mo_pop_Sim.csv"  # Replace with the actual path
big_pop_df = pd.read_csv(pop_file_path)
pop_df = big_pop_df.sample(frac=0.00005) 

pop_gdf = create_point_column(pop_df, 'long', 'lat', crs)
print(len(pop_gdf))
# Out:
# 317

# %%
pop_gdf.head()

# %% [markdown]
# ###
# EXPLANATION:
#
# In the below code, I have chosen Approach no.1 from the Assignment Question. I am choosing to calculate the average distance from residents to their nearest FQHC as the measure of fitness of the location.
#
# Why?
# It is simple and easy to understand, and it is also computationally efficient, running faster than alternative approaches. Also, this approach works better where there is uniform population density.
#
# What assumptions am I making?
# 1. Assuming equal importance of all residences, that is, there is even population density across all residences. This is unlikely to be true in the real world but as I don't know how the data is collected I am making this assumption.
# 2. Assuming average captures best accessibility, even though some residents may be very far.
# 3. Assuming distance is best indicator of accesibility: Actually, distance might not be the best determinant to accessibilty, since there are other factors like closeness to public transport, geographical barriers, etc.
#
# Describe your fitness function?
#     My fitness function takes two arguments,
#     1. the FQHC solution subset containing 8 FQHCs (from the initialized population) and
#     2. the population geoDataFrame which contains information about all the residences
#
#     First, both dataframes have re-projected Coordinate Reference System (CRS) to Missouri East (EPSG=26996).
#     Then, using sjoin_nearest, get information about nearest FQHCs in the subset, to all residences in pop_gdf. We store the geometry object as two different columns
#     Then, get distance between those two points and get mean value across all residences.
#     Then, apply a distance penalty when average distance is greater than 11,000mi - because I calculated the actual absolute minimum solution in this dataset and it is 11,000mi avg distance.
#     Then, divide by 10000 to get a smaller, easy to interpret fitness value.
#     Finally, return this fitness value.
#
# Since I am using average distance as the metric, I am aiming to *minimize* this value.
#
# ###

# %%
def fitness(fqhc_subset, pop_gdf):
    """
    Approach - Computing the average distance from residents to their nearest FQHC in the given subset.

    Args:
        fqhc_subset (GeoDataFrame): A subset of 8 selected FQHCs.
        pop_gdf (GeoDataFrame): The resident locations.

    Returns:
        float: The average distance between residents and their nearest FQHC.
    """
    # Ensure both datasets are in a projected CRS
    if pop_gdf.crs.is_geographic:
        pop_gdf = pop_gdf.to_crs(epsg=26996)  # Replace with your local projected CRS
    
    if fqhc_subset.crs.is_geographic:
        fqhc_subset = fqhc_subset.to_crs(epsg=26996)  # Same projection

    # Perform nearest spatial join
    nearest_fqhc = gpd.sjoin_nearest(pop_gdf, fqhc_subset, how="left")

    # Ensure correct column naming for FQHC geometry
    nearest_fqhc = nearest_fqhc.merge(fqhc_subset[['geometry']], left_on='OBJECTID', right_index=True, suffixes=('_pop', '_fqhc'))

    # Compute the average distance
    avg_distance = nearest_fqhc['geometry_pop'].distance(nearest_fqhc['geometry_fqhc']).mean()

    #getting distance penalty
    distance_penalty=0
    distance_penalty = max(0, avg_distance - 11000)
    
    fitness_value = (avg_distance + distance_penalty) / 10000
    return fitness_value

# %%
def initialize_population(gdf, pop_size):
    """
    Generate an initial population of random FQHC selections.
    
    Args:
        gdf (GeoDataFrame): Full list of FQHC locations.
        pop_size (int): Number of individuals (solutions) in the population.

    Returns:
        list: A list of subsets (each with 8 FQHCs).
    """
    population = []
    for _ in range(pop_size):
        individual = gdf.sample(n=8)  # Randomly select 8 FQHCs
        population.append(individual)
        
    return population

# %%
def perform_selection(population, pop_gdf, tournament_size=6):
    """
    Select parents using tournament selection.

    Args:
        population (list): List of FQHC subsets.
        pop_gdf (GeoDataFrame): Residents data.
        tournament_size (int): Number of individuals selected for each tournament.

    Returns:
        list: Two selected parents.
    """
    # Calculate the fitness of each individual
    fitness_values = [fitness(individual, pop_gdf) for individual in population]
    
    parents = []
    for _ in range(2):
        # Randomly select individuals for the tournament
        tournament = random.sample(list(zip(population, fitness_values)), tournament_size)
        
        # Find the individual with the best fitness (lowest fitness value)
        best_individual = min(tournament, key=lambda x: x[1])  # Assuming lower fitness is better
        parents.append(best_individual[0])  # Add the best individual to the parents list

    return parents

# %%
def crossover(parent1, parent2, crossover_rate = 0.85):
    """
    Perform crossover by swapping some FQHCs between parents.
    
    Args:
        parent1 (GeoDataFrame): First parent.
        parent2 (GeoDataFrame): Second parent.
        gdf (GeoDataFrame): Full dataset of FQHCs to sample from.
        crossover_rate (float): Probability of performing crossover.

    Returns:
        GeoDataFrame: A new child solution.
    """
    # SWAPPING FQHCs AT RANDOM POINTS IN THE SUBSET
    if random.random() < crossover_rate:
        crossover_point = random.randint(1, len(parent1) - 1)  
        child_fqhc = pd.concat([parent1.iloc[:crossover_point], parent2.iloc[crossover_point:]]).drop_duplicates()

        # Ensure exactly 8 FQHCs
        available_fqhc = gdf[~gdf.index.isin(child_fqhc.index)]
        while len(child_fqhc) < 8 and not available_fqhc.empty:
            additional_fqhc = available_fqhc.sample(1)
            child_fqhc = pd.concat([child_fqhc, additional_fqhc]).drop_duplicates()
            available_fqhc = available_fqhc[~available_fqhc.index.isin(child_fqhc.index)] 

    else:
        child_fqhc = parent1.copy()  # If there is no crossover, then clone one parent
    
    return child_fqhc

# %%
def mutate(individual, mutation_rate=0.45):
    """
    Randomly swap two FQHCs with new ones.

    Args:
        individual (GeoDataFrame): A subset of 8 FQHCs.
        gdf (GeoDataFrame): Full dataset of FQHCs to sample from.
        mutation_rate (float): Probability of mutation.

    Returns:
        GeoDataFrame: Mutated FQHC selection.
    """
    if random.random() < mutation_rate:
        mutated_individual = individual.copy()

        # Pick two distinct indices to replace
        replace_idxs = random.sample(range(8), 2)
        
        # Get available FQHCs (those not already in the individual)
        available_fqhc = gdf[~gdf.index.isin(mutated_individual.index)]
        
        if len(available_fqhc) >= 2:  # Ensure we have enough to swap
            new_fqhc = available_fqhc.sample(n=2)  # Pick two new random FQHCs
            #Insert them
            mutated_individual.iloc[replace_idxs[0]] = new_fqhc.iloc[0]
            mutated_individual.iloc[replace_idxs[1]] = new_fqhc.iloc[1]

        return mutated_individual
    
    return individual  # Return unchanged if mutation doesn't occur

# %%
def run_algorithm(gdf, pop_gdf, generations=100, pop_size=50, patience=5, reset_threshold=7, elitism_rate=1):
    """
    Run the genetic algorithm to find the best 8 FQHCs with early stopping.
    
    Args:
        gdf (GeoDataFrame): The full list of FQHCs.
        pop_gdf (GeoDataFrame): The resident locations.
        generations (int): Number of generations to run.
        pop_size (int): Number of individuals in each generation.
        patience (int): Number of generations without improvement before stopping early.

    Returns:
        GeoDataFrame: The best set of 8 FQHCs found.
    """
    population = initialize_population(gdf, pop_size)
    best_fitness = float('inf')  # Initialize with a high value
    stagnant_generations = 0  # Count generations without improvement

    for generation in range(generations):
        new_population = []

        # Select and retain elitism
        elites = sorted(population, key=lambda x: fitness(x, pop_gdf))[:elitism_rate]
        new_population.extend(elites)  # Start the new population with elites
        
        # Generate new offspring by performing selection, crossover, and mutation
        for _ in range(pop_size-elitism_rate):  
            parent1, parent2 = perform_selection(population, pop_gdf)
            child = crossover(parent1, parent2)
            child = mutate(child)  # Mutate the child
            new_population.append(child)

        assert len(new_population) == pop_size, "Population size mismatch!"
        population = new_population  # Update population
        
        # Track the best solution in this generation
        best_individual = min(population, key=lambda x: fitness(x, pop_gdf))
        best_fit = fitness(best_individual, pop_gdf)

        print(f"Generation {generation+1}: Best Fitness = {best_fit}")

        # Check for improvement
        if best_fit < best_fitness:
            best_fitness = best_fit
            stagnant_generations = 0  # Reset counter
        else:
            stagnant_generations += 1  # Increase counter

        if stagnant_generations >= reset_threshold:
            print(f"Population reset at Generation {generation+1}: No improvement for {reset_threshold} generations.")

            # **Keep the elite individual**
            new_population = [best_individual]  

            # **Reinitialize the rest of the population**
            new_population.extend(initialize_population(gdf, pop_size - 1))
            
            # **Reset stagnation counter**
            stagnant_generations = 0  

            # Update population
            population = new_population
            
        # Stop if no improvement for `patience` generations
        #if stagnant_generations >= patience:
            #print(f"Early stopping at Generation {generation+1}: No improvement for {patience} generations.")
            #break
    
    return best_individual  # Return best found solution

# %%
best_fqhc_set = run_algorithm(gdf, pop_gdf)
best_fqhc_set
# Out:
# Generation 1: Best Fitness = 7.8151220325025
# Generation 2: Best Fitness = 7.8151220325025
# Generation 3: Best Fitness = 7.745451269431784
# Generation 4: Best Fitness = 7.4192590555318265
# Generation 5: Best Fitness = 7.349547627364304
# Generation 6: Best Fitness = 7.349547627364304
# Generation 7: Best Fitness = 7.349547627364304
# Generation 8: Best Fitness = 7.349547627364304
# Generation 9: Best Fitness = 7.265251315968672
# Generation 10: Best Fitness = 7.156900906660789
# Generation 11: Best Fitness = 7.152577198252731
# Generation 12: Best Fitness = 7.152577198252731
# Generation 13: Best Fitness = 7.152577198252731
# Generation 14: Best Fitness = 7.152577198252731
# Generation 15: Best Fitness = 7.117642716905237
# Generation 16: Best Fitness = 6.935349403848059
# Generation 17: Best Fitness = 6.935349403848059
# Generation 18: Best Fitness = 6.859528810898159
# Generation 19: Best Fitness = 6.859528810898159
# Generation 20: Best Fitness = 6.859528810898159
# Generation 21: Best Fitness = 6.859528810898159
# Generation 22: Best Fitness = 6.859412803376435
# Generation 23: Best Fitness = 6.859412803376435
# Generation 24: Best Fitness = 6.859412803376435
# Generation 25: Best Fitness = 6.859412803376435
# Generation 26: Best Fitness = 6.859412803376435
# Generation 27: Best Fitness = 6.859412803376435
# Generation 28: Best Fitness = 6.859412803376435
# Generation 29: Best Fitness = 6.859412803376435
# Population reset at Generation 29: No improvement for 7 generations.
# Generation 30: Best Fitness = 6.859412803376435
# Generation 31: Best Fitness = 6.859412803376435
# Generation 32: Best Fitness = 6.859412803376435
# Generation 33: Best Fitness = 6.859412803376435
# Generation 34: Best Fitness = 6.859412803376435
# Generation 35: Best Fitness = 6.859412803376435
# Generation 36: Best Fitness = 6.859412803376435
# Population reset at Generation 36: No improvement for 7 generations.
# Generation 37: Best Fitness = 6.859412803376435
# Generation 38: Best Fitness = 6.859412803376435
# Generation 39: Best Fitness = 6.859412803376435
# Generation 40: Best Fitness = 6.859412803376435
# Generation 41: Best Fitness = 6.859412803376435
# Generation 42: Best Fitness = 6.836854576918346
# Generation 43: Best Fitness = 6.836854576918346
# Generation 44: Best Fitness = 6.836854576918346
# Generation 45: Best Fitness = 6.834196245419913
# Generation 46: Best Fitness = 6.725015703620919
# Generation 47: Best Fitness = 6.725015703620919
# Generation 48: Best Fitness = 6.725015703620919
# Generation 49: Best Fitness = 6.725015703620919
# Generation 50: Best Fitness = 6.725015703620919
# Generation 51: Best Fitness = 6.725015703620919
# Generation 52: Best Fitness = 6.725015703620919
# Generation 53: Best Fitness = 6.725015703620919
# Population reset at Generation 53: No improvement for 7 generations.
# Generation 54: Best Fitness = 6.725015703620919
# Generation 55: Best Fitness = 6.725015703620919
# Generation 56: Best Fitness = 6.725015703620919
# Generation 57: Best Fitness = 6.644258708498936
# Generation 58: Best Fitness = 6.644258708498936
# Generation 59: Best Fitness = 6.644258708498936
# Generation 60: Best Fitness = 6.644258708498936
# Generation 61: Best Fitness = 6.644258708498936
# Generation 62: Best Fitness = 6.644258708498936
# Generation 63: Best Fitness = 6.644258708498936
# Generation 64: Best Fitness = 6.644258708498936
# Population reset at Generation 64: No improvement for 7 generations.
# Generation 65: Best Fitness = 6.644258708498936
# Generation 66: Best Fitness = 6.644258708498936
# Generation 67: Best Fitness = 6.644258708498936
# Generation 68: Best Fitness = 6.644258708498936
# Generation 69: Best Fitness = 6.644258708498936
# Generation 70: Best Fitness = 6.644258708498936
# Generation 71: Best Fitness = 6.644258708498936
# Population reset at Generation 71: No improvement for 7 generations.
# Generation 72: Best Fitness = 6.644258708498936
# Generation 73: Best Fitness = 6.644258708498936
# Generation 74: Best Fitness = 6.644258708498936
# Generation 75: Best Fitness = 6.644258708498936
# Generation 76: Best Fitness = 6.644258708498936
# Generation 77: Best Fitness = 6.644258708498936
# Generation 78: Best Fitness = 6.644258708498936
# Population reset at Generation 78: No improvement for 7 generations.
# Generation 79: Best Fitness = 6.644258708498936
# Generation 80: Best Fitness = 6.644258708498936
# Generation 81: Best Fitness = 6.644258708498936
# Generation 82: Best Fitness = 6.644258708498936
# Generation 83: Best Fitness = 6.596897151259135
# Generation 84: Best Fitness = 6.596897151259135
# Generation 85: Best Fitness = 6.596897151259135
# Generation 86: Best Fitness = 6.596897151259135
# Generation 87: Best Fitness = 6.596897151259135
# Generation 88: Best Fitness = 6.596897151259135
# Generation 89: Best Fitness = 6.596897151259135
# Generation 90: Best Fitness = 6.596897151259135
# Population reset at Generation 90: No improvement for 7 generations.
# Generation 91: Best Fitness = 6.596897151259135
# Generation 92: Best Fitness = 6.596897151259135
# Generation 93: Best Fitness = 6.596897151259135
# Generation 94: Best Fitness = 6.596897151259135
# Generation 95: Best Fitness = 6.444584638375667
# Generation 96: Best Fitness = 6.444584638375667
# Generation 97: Best Fitness = 6.444584638375667
# Generation 98: Best Fitness = 6.444584638375667
# Generation 99: Best Fitness = 6.444584638375667
# Generation 100: Best Fitness = 6.444584638375667
#                                       Group_Name  \
# OBJECTID
# 145        Jordan Valley Community Health Center
# 195       Betty Jean Kerr People's Health Center
# 187                         Family Health Center
# 137                  Cross Trails Medical Center
# 42                  Your Community Health Center
# 81        Betty Jean Kerr People's Health Center
# 154                    Northwest Health Services
# 47               Samuel U. Rodgers Health Center
#
#                                                    Facility  \
# OBJECTID
# 145       Jordan Valley Community Health - Mobile Dental...
# 195                              Mobile Van Health Services
# 187            Family Health Center East (Medical & Dental)
# 137                             Cross Trails Medical Center
# 42         Your Community Health Center - Health Department
# 81        Betty Jean Kerr People's Health Center, Inc. (...
# 154                                        King City Clinic
# 47        Samuel U. Rodgers Health Center-J.A. Rogers Fa...
#
#                             Address         City          County State    Zip  \
# OBJECTID
# 145         618 North Benton Avenue  Springfield          Greene    MO  65806
# 195           5701 Delmar Boulevard    St. Louis  St. Louis City    MO  63112
# 187            2475 Broadway Bluffs     Columbia           Boone    MO  65201
# 137                     307 Gabriel      Advance        Stoddard    MO  63730
# 42        200 North Main, Suite G51        Rolla          Phelps    MO  65401
# 81            5701 Delmar Boulevard    St. Louis  St. Louis City    MO  63112
# 154                305 Rhode Island    King City          Gentry    MO  64463
# 47              6400 E. 23rd Street  Kansas City         Jackson    MO  64129
#
#                Phone   Latitude  Longitude Loc_Code  \
# OBJECTID
# 145       4178310150  37.214148 -93.287538      MAP
# 195       3143677848  38.654260 -90.285449      MAP
# 187       5737779282  38.947776 -92.302101      MAP
# 137       5737223034  37.104129 -89.911496      MAP
# 42        5734586950  37.945925 -91.773948      MAP
# 81        3143677848  38.654260 -90.285449      MAP
# 154       6605354347  40.054075 -94.526467      MAP
# 47        8162315746  39.083164 -94.507583      MAP
#
#                             geometry
# OBJECTID
# 145       POINT (-93.28747 37.21445)
# 195        POINT (-90.28545 38.6543)
# 187       POINT (-92.30213 38.94781)
# 137        POINT (-89.9115 37.10413)
# 42        POINT (-91.77391 37.94594)
# 81         POINT (-90.28545 38.6543)
# 154        POINT (-94.52652 40.0541)
# 47         POINT (-94.50762 39.0832)

# %%
##THESE ARE THE 8 BEST FQHCs AFTER RUNNING THE ALGORITHM
pd.set_option('display.max_colwidth', None)
best_fqhc_set['Facility']
# Out:
# OBJECTID
# 145                Jordan Valley Community Health - Mobile Dental Unit
# 195                                         Mobile Van Health Services
# 187                       Family Health Center East (Medical & Dental)
# 137                                        Cross Trails Medical Center
# 42                    Your Community Health Center - Health Department
# 81     Betty Jean Kerr People's Health Center, Inc. (Corporate Office)
# 154                                                   King City Clinic
# 47           Samuel U. Rodgers Health Center-J.A. Rogers Family Dental
# Name: Facility, dtype: object

# %% [markdown]
# ###
# The above table and output show the top 8 FQHCs according to average distance that were generated from my Genetic Algorithm.
#
# Some possible limitations to this approach include:
# 1. Max generations - my model was still decreasing the avg_distance but rano out of generations. I could increase generations but it would increase compute time.
# 2. Population size - a higher pop size would increase diversity of initial solutions, however increasing population size any more would greatly increase compute time.
# 3. tournament size
# 4. crossover rate
# 5. mutation rate
#
# ###
